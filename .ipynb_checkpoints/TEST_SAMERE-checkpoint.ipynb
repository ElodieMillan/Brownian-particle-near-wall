# %%
import numpy as np
import matplotlib.pyplot as plt


from RigidWallOverdampedLangevin3D import RigidWallOverdampedLangevin3D

# %%
R = 1e-6

# %%
zi_1 = np.linspace(0, 100e-6, 10000)

# %%
eta_eta0xy = (1 - ((9 * R) / (16 * (zi_1 + R))) + (R / (8*(zi_1+R)))**3 - (45*R / (256*(zi_1+R)))**4 - (R / (16*(zi_1+R)))**5 ) ** (-1)

# %%
plt.semilogx(zi_1*1e6, 1/eta_eta0xy)

# %%
np.min(1/eta_eta0)
# Out:
# 0.4384974201675505

# %%
eta_eta0z = (9 * R / (8 * zi_1))
# Out:
# <ipython-input-71-af853677891f>:1: RuntimeWarning: divide by zero encountered in true_divide
#   eta_eta0z = (9 * R / (8 * zi_1))

# %%
plt.loglog(zi_1*1e6, 1/eta_eta0z)

# %%
pade_eta_z = ((6*zi_1**2 + 2*R*zi_1) / (6*zi_1**2 + 9*R*zi_1 + 2*R**2))

# %%
plt.loglog(zi_1*1e6, pade_eta_z)
plt.loglog(zi_1*1e6, 1/eta_eta0z)

# %%
gamma_z = (6* np.pi* self.R* self.eta* 
           (((6 * zi_1 ** 2 + 2 * self.R * zi_1)
            /(6 * zi_1 ** 2 + 9 * self.R * zi_1 + 2 * self.R ** 2)
            )** (-1)))
